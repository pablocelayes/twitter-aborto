# %%
#We will start first by uploading json and pandas using the commands below:
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Next we will read the data in into an array that we call tweets.
tweets_data_path = '../data/tweets_no.json'

tweets_file = open(tweets_data_path, "r")
tweets_data = json.load(tweets_file)

# %%
len(tweets_data)
# Out:
# 1847

# %%
# veamos un tweet de ejemplo
tweets_data[0]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Apr 17 11:40:55 +0000 2018',
#  'entities': {'hashtags': [{'indices': [46, 57], 'text': 'NoAlAborto'}],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 167900487,
#     'id_str': '167900487',
#     'indices': [3, 15],
#     'name': 'LazosdeAmorMariano',
#     'screen_name': 'LAM_Oficial'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 986207876367732736,
#  'id_str': '986207876367732736',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'es',
#  'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 12,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Apr 17 00:59:59 +0000 2018',
#   'entities': {'hashtags': [{'indices': [29, 40], 'text': 'NoAlAborto'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
#   'favorite_count': 21,
#   'favorited': False,
#   'geo': None,
#   'id': 986046582020870144,
#   'id_str': '986046582020870144',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 12,
#   'retweeted': False,
#   'source': '<a href="http://www.lazosdeamormariano.net" rel="nofollow">Auto Tweeter LAM</a>',
#   'text': '¡Si a la Vida!¡No al aborto! #NoAlAborto',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Jul 17 20:48:14 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Movimiento Católico Lazos de Amor Mariano ¡Nacimos en la Iglesia y para la Iglesia!',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'lazosdeamormariano.net',
#        'expanded_url': 'http://www.lazosdeamormariano.net',
#        'indices': [0, 22],
#        'url': 'http://t.co/o3kEYJO13o'}]}},
#    'favourites_count': 261,
#    'follow_request_sent': None,
#    'followers_count': 29478,
#    'following': None,
#    'friends_count': 153,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 167900487,
#    'id_str': '167900487',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 98,
#    'location': 'Medellín  - Colombia',
#    'name': 'LazosdeAmorMariano',
#    'notifications': None,
#    'profile_background_color': '5C3713',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/741903700/db55b3fdd5941cbb9d5666389b2705fc.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/741903700/db55b3fdd5941cbb9d5666389b2705fc.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/167900487/1467672659',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/754302946754629632/n5HD-X8G_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/754302946754629632/n5HD-X8G_normal.jpg',
#    'profile_link_color': 'B30024',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'E6E2DD',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'LAM_Oficial',
#    'statuses_count': 57715,
#    'time_zone': 'Bogota',
#    'translator_type': 'none',
#    'url': 'http://t.co/o3kEYJO13o',
#    'utc_offset': -18000,
#    'verified': False}},
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'text': 'RT @LAM_Oficial: ¡Si a la Vida!¡No al aborto! #NoAlAborto',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Sat Jun 27 18:43:45 +0000 2009',
#   'default_profile': True,
#   'default_profile_image': False,
#   'description': 'Antioqueño,',
#   'entities': {'description': {'urls': []}},
#   'favourites_count': 4610,
#   'follow_request_sent': None,
#   'followers_count': 114,
#   'following': None,
#   'friends_count': 137,
#   'geo_enabled': True,
#   'has_extended_profile': True,
#   'id': 51518444,
#   'id_str': '51518444',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'es',
#   'listed_count': 1,
#   'location': 'Medellín, Antioquia',
#   'name': 'john giraldo',
#   'notifications': None,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/477823069881655296/4B9oeDQZ_normal.jpeg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/477823069881655296/4B9oeDQZ_normal.jpeg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'johnjagiga',
#   'statuses_count': 9728,
#   'time_zone': 'Bogota',
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': -18000,
#   'verified': False}}

# %%
# Recortemos los datos a lo que nos interesa por ahora
def recortar_tweet(t):
    COLUMNAS = ['created_at', 'favorite_count', 'retweet_count', 'text']
    tweet_recortado = {columna: t[columna] for columna in COLUMNAS}
    tweet_recortado['user_name'] = t['user']['name']
    return tweet_recortado

# %%
recortar_tweet(tweets_data[0])
# Out:
# {'created_at': 'Tue Apr 17 11:40:55 +0000 2018',
#  'favorite_count': 0,
#  'retweet_count': 12,
#  'text': 'RT @LAM_Oficial: ¡Si a la Vida!¡No al aborto! #NoAlAborto',
#  'user_name': 'john giraldo'}

# %%
# Armamos un dataframe con los tweets recortados
#we will structure the tweets data into a pandas DataFrame
recortados = [recortar_tweet(t) for t in tweets_data]
tweets = pd.DataFrame(recortados)

# %%
# veamos como quedó el Dataframe
tweets
# Out:
#                           created_at  favorite_count  retweet_count  \
# 0     Tue Apr 17 11:40:55 +0000 2018               0             12
# 1     Tue Apr 17 11:38:08 +0000 2018               0             24
# 2     Tue Apr 17 11:15:34 +0000 2018               0             37
# 3     Tue Apr 17 11:12:13 +0000 2018               0              0
# 4     Tue Apr 17 11:05:41 +0000 2018               0              9
# 5     Tue Apr 17 11:02:42 +0000 2018               0              0
# 6     Tue Apr 17 10:57:21 +0000 2018               0              9
# 7     Tue Apr 17 10:56:46 +0000 2018               0              0
# 8     Tue Apr 17 10:55:37 +0000 2018               0              0
# 9     Tue Apr 17 10:45:30 +0000 2018               0              0
# 10    Tue Apr 17 10:44:45 +0000 2018               0             13
# 11    Tue Apr 17 10:40:16 +0000 2018               0             24
# 12    Tue Apr 17 10:39:23 +0000 2018               0              0
# 13    Tue Apr 17 10:33:45 +0000 2018               0             37
# 14    Tue Apr 17 10:15:03 +0000 2018               0             24
# 15    Tue Apr 17 10:11:44 +0000 2018               0             15
# 16    Tue Apr 17 10:05:05 +0000 2018               0             10
# 17    Tue Apr 17 10:01:30 +0000 2018               0             13
# 18    Tue Apr 17 09:46:41 +0000 2018               0              1
# 19    Tue Apr 17 09:40:08 +0000 2018               0             12
# 20    Tue Apr 17 09:22:02 +0000 2018               1              1
# 21    Tue Apr 17 09:14:51 +0000 2018               0              0
# 22    Tue Apr 17 09:13:13 +0000 2018               0             10
# 23    Tue Apr 17 09:06:15 +0000 2018               0              6
# 24    Tue Apr 17 08:54:24 +0000 2018               0              9
# 25    Tue Apr 17 08:51:01 +0000 2018               0             15
# 26    Tue Apr 17 08:37:54 +0000 2018               0             15
# 27    Tue Apr 17 07:15:51 +0000 2018               0              0
# 28    Tue Apr 17 07:07:45 +0000 2018               0             13
# 29    Tue Apr 17 06:57:01 +0000 2018               0             15
# ...                              ...             ...            ...
# 1817  Sat Apr 14 00:39:36 +0000 2018               0             11
# 1818  Sat Apr 14 00:37:39 +0000 2018               0            210
# 1819  Sat Apr 14 00:35:45 +0000 2018               0            210
# 1820  Sat Apr 14 00:26:21 +0000 2018               0             35
# 1821  Sat Apr 14 00:26:15 +0000 2018               0             23
# 1822  Sat Apr 14 00:22:53 +0000 2018               0              5
# 16                             patricia leguizamo
# 17                                           Caro
# 18                               Flavio Mandrilli
# 19                             Lucia G. Macias 🇻🇪
# 20                             Raul Rodriguez ✝🇦🇷
# 21                                 Sergio Arévalo
# 22                               Yanii Albarracin
# 23                              Aureliano Buendía
# 24                           Cripple Latino Doggo
# 25                                  Chiki & Bella
# 26                                🇪🇸 Ignacio 🇪🇸 ن
# 27                             Jose R. Valladares
# 28                                   Henry Araujo
# 29                               🇪🇸 Ignacio 🇪🇸 ن‏
# ...                                           ...
# 1817                                      Valee 🌙
# 1818                          Eduardo Mantilla H.
# 1819                          Princesa consentida
# 1820                                Sarahi Molina
# 1821                            Jose eduardo josa
# 1822                                 Silvia Bordo
# 1823                                Carlos Angulo
# 1824                                    posteviur
# 1825                              Joanna Gonzalez
# 1826                                 Rene Ramirez
# 1827                                József Bozsik
# 1828                             Voto Catolico ES
# 1829                         E. Vázquez-Bécker S.
# 1830                                      DR. GIO
# 1831                                        EmmaH
# 1832                           Santa Biblia 840AM
# 1833                             Juanjose Sanchez
# 1834                                  José Manuel
# 1835                                   Nony Araoz
# 1836                         Parrquia Divino Niño
# 1837                         E. Vázquez-Bécker S.
# 1838                                 john giraldo
# 1839                                        LAURA
# 1840                                      Narcisa
# 1841                                  Cindy Paola
# 1842                         Jesús MatheusLinares
# 1843                                    Claudia O
# 1844                                 Fredis Jovel
# 1845                                     Breeen 🌈
# 1846                           Bautista Péntecost
#
# [1847 rows x 5 columns]

# %%
# vemos los tipos de datos de cada columna ( los que puso pandas por defecto )
tweets.dtypes
# Out:
# created_at        object
# favorite_count     int64
# retweet_count      int64
# text              object
# user_name         object
# dtype: object

# %%
# Para que sean las fechas sean más sencillas de manipular conviene
# que created_at sea tratada como fecha
# La convertimos:
tweets['created_at'] = pd.to_datetime(tweets['created_at'])
tweets.dtypes
# Out:
# created_at        datetime64[ns]
# favorite_count             int64
# retweet_count              int64
# text                      object
# user_name                 object
# dtype: object

# %%
tweets.head()
# Out:
#            created_at  favorite_count  retweet_count  \
# 0 2018-04-17 11:40:55               0             12
# 1 2018-04-17 11:38:08               0             24
# 2 2018-04-17 11:15:34               0             37
# 3 2018-04-17 11:12:13               0              0
# 4 2018-04-17 11:05:41               0              9
#
#                                                 text          user_name
# 0  RT @LAM_Oficial: ¡Si a la Vida!¡No al aborto! ...       john giraldo
# 1  RT @PattRam74: Ahora a la izquierda le dió con...      Mario Astorga
# 2  RT @BalleriniVIDA: Las mujeres pobres aman a s...      jorge antunez
# 3  @clarincom "La preocupación por la vida no ata...  Veronica Vocos 🇦🇷
# 4  RT @VotoCatolicoES: #NoAlAborto \nEL DÍA EN QU...   Janet Cienfuegos

# %% [markdown]
# ## ¿Cómo seguimos?
#
# 1. Agrupar por hora y graficar cantidad de tweets por hora
#
# 2. Hacer lo mismo para los tweets del sí
#
# 3. Hacer un gráfico comparativo donde aparezcan juntos los tweets por hora del sí y del no
